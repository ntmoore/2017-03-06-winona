# %%
import pandas

# %%
filepath="~/monday_afternoon_python/data/gapminder_gdp_oceania.csv"
data_oc=pandas.read_csv(filepath,index_col="country")

# %%
print(data_oc)
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
print(data_oc.T)
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751  16233.71770
# gdpPercap_1982  19477.00928  17632.41040
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
print(data_oc.T.head())
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728

# %%
data_oc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, Australia to New Zealand
# Data columns (total 12 columns):
# gdpPercap_1952    2 non-null float64
# gdpPercap_1957    2 non-null float64
# gdpPercap_1962    2 non-null float64
# gdpPercap_1967    2 non-null float64
# gdpPercap_1972    2 non-null float64
# gdpPercap_1977    2 non-null float64
# gdpPercap_1982    2 non-null float64
# gdpPercap_1987    2 non-null float64
# gdpPercap_1992    2 non-null float64
# gdpPercap_1997    2 non-null float64
# gdpPercap_2002    2 non-null float64
# gdpPercap_2007    2 non-null float64
# dtypes: float64(12)
# memory usage: 208.0+ bytes

# %%
data_oc.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        2.000000        2.000000        2.000000
# mean     10298.085650    11598.522455    12696.452430    14495.021790
# std        365.560078      917.644806      677.727301       43.986086
# min      10039.595640    10949.649590    12217.226860    14463.918930
# 25%      10168.840645    11274.086022    12456.839645    14479.470360
# 50%      10298.085650    11598.522455    12696.452430    14495.021790
# 75%      10427.330655    11922.958888    12936.065215    14510.573220
# max      10556.575660    12247.395320    13175.678000    14526.124650
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count         2.00000        2.000000        2.000000        2.000000
# mean      16417.33338    17283.957605    18554.709840    20448.040160
# std         525.09198     1485.263517     1304.328377     2037.668013
# ...

# %%
print(data_oc.columns)
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
filepath="~/monday_afternoon_python/data/gapminder_gdp_americas.csv"
data_am=pandas.read_csv(filepath,index_col="country")

# %%
data_am.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      4079.062552     4616.043733     4901.541870     5668.253496
# std       3001.727522     3312.381083     3421.740569     4160.885560
# min       1397.717137     1544.402995     1662.137359     1452.057666
# 25%       2428.237769     2487.365989     2750.364446     3242.531147
# 50%       3048.302900     3780.546651     4086.114078     4643.393534
# 75%       3939.978789     4756.525781     5180.755910     5788.093330
# max      13990.482080    14847.127120    16173.145860    19530.365570
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      6491.334139     7352.007126     7506.737088     7793.400261
# std       4754.404329     5355.602518     5530.490471     6665.039509
# ...

# %%
temp=data_am.T
temp.to_csv("transposed_americas.csv")

# %%
print(data_am.ix["Panama":"Peru","gdpPercap_1952":"gdpPercap_1973"])
# Out:
#           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Panama       2480.380334     2961.800905     3536.540301     4421.009084
# Paraguay     1952.308701     2046.154706     2148.027146     2299.376311
# Peru         3758.523437     4245.256698     4957.037982     5788.093330
#
#           gdpPercap_1972
# country
# Panama       5364.249663
# Paraguay     2523.337977
# Peru         5937.827283

# %%
print(data_am.ix["Panama":"Peru",("gdpPercap_1952","gdpPercap_1982")])
# Out:
#           gdpPercap_1952  gdpPercap_1982
# country
# Panama       2480.380334     7009.601598
# Paraguay     1952.308701     4258.503604
# Peru         3758.523437     6434.501797

# %%
print(data_am.ix["Panama":"Peru","gdpPercap_1967":])
# Out:
#           gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Panama       4421.009084     5364.249663     5351.912144     7009.601598
# Paraguay     2299.376311     2523.337977     3248.373311     4258.503604
# Peru         5788.093330     5937.827283     6281.290855     6434.501797
#
#           gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# country
# Panama       7034.779161     6618.743050     7113.692252     7356.031934
# Paraguay     3998.875695     4196.411078     4247.400261     3783.674243
# Peru         6360.943444     4446.380924     5838.347657     5909.020073
#
#           gdpPercap_2007
# country
# Panama       9809.185636
# Paraguay     4172.838464
# Peru         7408.905561

# %%
mask=data_am>10000
print(mask)
# Out:
#                     continent gdpPercap_1952 gdpPercap_1957 gdpPercap_1962  \
# country
# Argentina                True          False          False          False
# Bolivia                  True          False          False          False
# Brazil                   True          False          False          False
# Canada                   True           True           True           True
# Chile                    True          False          False          False
# Colombia                 True          False          False          False
# Costa Rica               True          False          False          False
# Cuba                     True          False          False          False
# Dominican Republic       True          False          False          False
# Ecuador                  True          False          False          False
# El Salvador              True          False          False          False
# ...

# %%
data_am[mask]
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina            Americas             NaN             NaN             NaN
# Bolivia              Americas             NaN             NaN             NaN
# Brazil               Americas             NaN             NaN             NaN
# Canada               Americas     11367.16112     12489.95006     13462.48555
# Chile                Americas             NaN             NaN             NaN
# Colombia             Americas             NaN             NaN             NaN
# Costa Rica           Americas             NaN             NaN             NaN
# Cuba                 Americas             NaN             NaN             NaN
# Dominican Republic   Americas             NaN             NaN             NaN
# Ecuador              Americas             NaN             NaN             NaN
# El Salvador          Americas             NaN             NaN             NaN
# ...

# %%
data_am.ix["Panama":"Peru",:].max()
# Out:
# continent         Americas
# gdpPercap_1952     3758.52
# gdpPercap_1957     4245.26
# gdpPercap_1962     4957.04
# gdpPercap_1967     5788.09
# gdpPercap_1972     5937.83
# gdpPercap_1977     6281.29
# gdpPercap_1982      7009.6
# gdpPercap_1987     7034.78
# gdpPercap_1992     6618.74
# gdpPercap_1997     7113.69
# gdpPercap_2002     7356.03
# gdpPercap_2007     9809.19
# dtype: object

# %% [markdown]
# Practice with Selection

# %%
# import the Europe data
filepath="~/monday_afternoon_python/data/gapminder_gdp_europe.csv"
data_eu=pandas.read_csv(filepath,index_col="country")
data_eu.head()
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Albania                    2760.196931     3313.422188     3533.003910
# Austria                   12834.602400    16661.625600    19749.422300
# Belgium                   13149.041190    16672.143560    19117.974480
# Bosnia and Herzegovina     2172.352423     2860.169750     3528.481305
# Bulgaria                   5577.002800     6597.494398     7612.240438
#
#                         gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# ...

# %%
# GDP per capita for all countries in 1982
data_eu.ix[:,"gdpPercap_1982"]
# Out:
# country
# Albania                    3630.880722
# Austria                   21597.083620
# Belgium                   20979.845890
# Bosnia and Herzegovina     4126.613157
# Bulgaria                   8224.191647
# Croatia                   13221.821840
# Czech Republic            15377.228550
# Denmark                   21688.040480
# Finland                   18533.157610
# France                    20293.897460
# Germany                   22031.532740
# Greece                    15268.420890
# Hungary                   12545.990660
# Iceland                   23269.607500
# Ireland                   12618.321410
# Italy                     16537.483500
# Montenegro                11222.587620
# Netherlands               21399.460460
# Norway                    26298.635310
# Poland                     8451.531004
# Portugal                  11753.842910
# Romania                    9605.314053
# Serbia                    15181.092700
# Slovak Republic           11348.545850
# ...

# %%
# GDP per capita for Denmark for all years
data_eu.ix["Denmark",:]
# Out:
# gdpPercap_1952     9692.385245
# gdpPercap_1957    11099.659350
# gdpPercap_1962    13583.313510
# gdpPercap_1967    15937.211230
# gdpPercap_1972    18866.207210
# gdpPercap_1977    20422.901500
# gdpPercap_1982    21688.040480
# gdpPercap_1987    25116.175810
# gdpPercap_1992    26406.739850
# gdpPercap_1997    29804.345670
# gdpPercap_2002    32166.500060
# gdpPercap_2007    35278.418740
# Name: Denmark, dtype: float64

# %%
# GDP per capita for all countries for years after 1985
data_eu.ix[:,"gdpPercap_1985":]
# Out:
#                         gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  \
# country
# Albania                    3738.932735     2497.437901     3193.054604
# Austria                   23687.826070    27042.018680    29095.920660
# Belgium                   22525.563080    25575.570690    27561.196630
# Bosnia and Herzegovina     4314.114757     2546.781445     4766.355904
# Bulgaria                   8239.854824     6302.623438     5970.388760
# Croatia                   13822.583940     8447.794873     9875.604515
# Czech Republic            16310.443400    14297.021220    16048.514240
# Denmark                   25116.175810    26406.739850    29804.345670
# Finland                   21141.012230    20647.164990    23723.950200
# France                    22066.442140    24703.796150    25889.784870
# Germany                   24639.185660    26505.303170    27788.884160
# Greece                    16120.528390    17541.496340    18747.698140
# ...

# %%
# GDP per capita for each country in 2007 as a 
# multiple of the
